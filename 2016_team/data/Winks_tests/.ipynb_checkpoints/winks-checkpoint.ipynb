# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
dL = pd.read_csv('Robin-1L-03.10.16.17.15.11.csv')
dR = pd.read_csv('Robin-1R-03.10.16.17.10.28.csv')

# %%
#lines = open('../data_real/eeg_zhanna_channels.txt').readlines()
#lines = lines[1:]
#lines = [line.strip() for line in lines]

#CHANNELS = dict()
#for line in lines:
 #   num, _, label = line.partition(' ')
#  num = int(num) - 1
 #    CHANNELS[num] = label

# %%
dL.shape, dR.shape
# Out:
# ((15744, 15), (15744, 15))

# %%
dR.head()
# Out:
#      channel_0    channel_1    channel_2    channel_3    channel_4  \
# 0  4410.256348  4196.922852  4196.410156  4168.717773  4177.436035
# 1  4401.538574  4191.794922  4197.436035  4168.205078  4173.333008
# 2  4401.025391  4200.000000  4200.000000  4187.692383  4181.538574
# 3  4397.435547  4200.512695  4199.487305  4188.717773  4190.769043
# 4  4375.897461  4189.230469  4198.974121  4172.307617  4189.230469
#
#      channel_5    channel_6    channel_7    channel_8    channel_9  \
# 0  4199.487305  4198.974121  4190.256348  4165.641113  4274.358887
# 1  4199.487305  4198.974121  4184.102539  4176.410156  4276.410156
# 2  4197.436035  4198.974121  4168.717773  4184.102539  4280.000000
# 3  4198.974121  4198.974121  4166.153809  4172.307617  4279.487305
# 4  4197.436035  4198.974121  4169.230469  4167.179199  4285.127930
#
#     channel_10   channel_11   channel_12   channel_13  Time
# 0  4166.153809  4180.000000  4171.281738  4181.025391     0
# 1  4175.897461  4179.487305  4171.281738  4181.538574     1
# 2  4183.589844  4184.615234  4180.512695  4185.127930     2
# 3  4167.179199  4181.538574  4177.948730  4184.615234     3
# 4  4156.922852  4177.436035  4169.230469  4184.102539     4

# %%
#for column in dR:
    
#    plt.figure()
    #plt.specgram(d[column], NFFT=128, Fs=250, noverlap=64)
#    plt.plot(dR[column])
#    plt.title(column)

# %%
eeg = np.array(dL.ix[:, 0:13])
eeg = eeg[250:77500,]

#tag = np.array(d.ix[:, 'tag'])
#tag = tag[250:]

# %%
from scipy import signal

# %%
# filter from 5 to 35 Hz, helps remove 60Hz noise and replicates paper
## also helps remove the DC line noise (baseline drift)
## 125 is half the sampling rate (250Hz/2)
b, a = signal.butter(4, (2.0/125, 35.0/125), btype='bandpass') 
b, a
# Out:
# (array([ 0.01222321,  0.        , -0.04889285,  0.        ,  0.07333928,
#          0.        , -0.04889285,  0.        ,  0.01222321]),
#  array([  1.        ,  -5.71974179,  14.41372236, -21.04755049,
#          19.59013879, -11.93007722,   4.63594027,  -1.04851038,   0.10608002]))

# %%
eeg_f = signal.lfilter(b, a, eeg, axis=0)

# %%
## the filter needs a couple samples to converge
## honestly 500 is very conservative, but we don't these samples anyway so whatever
eeg_f = eeg_f[500:]

# %%
plt.figure(figsize=(14, 4))
plt.plot(eeg[500:1000, 7]) ## raw data

# %%
plt.figure(figsize=(14, 4))
plt.plot(eeg_f[:500, 7])

# %%
from sklearn.decomposition import FastICA

# %%
ica = FastICA()
sources = ica.fit_transform(eeg_f)
means = ica.mean_.copy()
mixing = ica.mixing_.copy()

# %%
import binascii
import matplotlib.pyplot as plt
import pandas as pd
from scipy import signal
import csv
import numpy as np
from scipy.cluster.vq import kmeans2,whiten

# %%
def somme (a, i1, i2):
    s=0.0
    for i in range(i2+1-i1):
        s=s+a[i1+i]
    return s

# %%
def ploter(a):
    plt.plot(a)
    plt.ylabel('some numbers')
    plt.show()

# %%
g= open('../Robin-1L-03.10.16.17.15.11.csv','rb')
gcsv = csv.reader(g, delimiter=',')
l = []
compteur = 0
for row in gcsv:
    if (compteur!=0):
        l.append(float(row[2])+float(row[3])+float(row[11]))
    compteur = compteur + 1

# %%
def traiter(l,l_chunk,nb_clusters):
    size = (len(l)/l_chunk)-1
    a = np.zeros((size,l_chunk))
    st= np.zeros((size,1))
    a2 = np.zeros((size,l_chunk))
    st2=np.zeros((size,1))
    
    for i in range(size):
        for j in range(l_chunk):
            a[i,j]= l[i*l_chunk+j]
            a2[i,j]= l[i*l_chunk+j+(l_chunk/2)]
        st[i,0]=somme(a[i],0,l_chunk-1)
        st2[i,0]= somme(a2[i],0,l_chunk-1)
    
    continuum = np.zeros((2*size,1))
    c2=np.zeros((2*size,l_chunk))
    for i in range(size):
        continuum[2*i,0]=st[i,0]
        continuum[2*i+1,0]=st2[i,0]
        c2[2*i]=a[i]
        c2[2*i+1]=a2[i]

    w = whiten(continuum)
    
    k, c = kmeans2(w,nb_clusters,50, minit='points')
    print k
    print c
    plt.plot(c)
    plt.ylabel('some numbers')
    plt.show()
    
    ind_imp= 0
    ou1 = somme(c,0,len(c)-1)
    if (ou1<len(c)/2):
        ind_imp=1
    else:
        ou1=len(c)-ou1
        
    inds = []
    for i in range(len(c)):
        if (c[i]==ind_imp):
            inds.append(i)
    
    print inds
    for i in inds:
        ploter(c2[i])
    return ou1

# %%
def trouver_l_chunk(l_min,rang):    
    for j in range(5):
        li = []
        for i in range (rang):
            li.append(traiter(l,rang + l_min,2))
        ploter(li)
        return min(li),li.index(min(li))

traiter(l,95,2)
